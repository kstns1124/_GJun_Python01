# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import pandas as pd

# %%
x = np.arange(5)
y = np.array([5,2,9,3,8]) * 1000

font1 = FontProperties(fname='/usr/share/fonts/truetype/wqy/wqy-zenhei.ttc',size=12)

fig = plt.figure(figsize=(10,5))
axes1 = fig.add_subplot(1,1,1)
axes1.grid(axis='y')
axes1.bar(x, y)
axes1.set_xticks(x, ['apple', 'banana', 'orange', 'tomato', 'grava'])
axes1.legend()
# print(axes1.axis())
xmin,xmax, ymin,ymax = axes1.axis()
axes1.axis(xmin = xmin - (xmax-xmin)*0.05
    , xmax = xmax+ (xmax-xmin)*0.05
    , ymin = ymin
    , ymax = ymax + (ymax-ymin)*0.05)

for x in axes1.get_xticks():
    val1 = y [x]
    axes1.annotate(text=str(val1), xy=(x-0.15, val1+1.0*100), color='red' ,fontproperties=font1
                  #, arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.95', color='b')
                  )

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# (-0.6400000000000001, 4.640000000000001, 0.0, 9450.0)

# %%
#Pandas
s01 = pd.Series(data = [x for x in range(5)], index=['a', 'b', 'c', 'd', 'f'])
print(s01[0])
print(s01['f'])
# Out:
# 0
# 4
# /tmp/ipykernel_961/3084556545.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s01[0])
