# %%
codes = {'tw':'Taiwan', 'jp': 'Japan'}
print(codes)
print(list(codes.keys())[0], list(codes.values())[0])
# Out:
# {'tw': 'Taiwan', 'jp': 'Japan'}
# tw Taiwan

# %%
codes['hk'] = "Hong Kong"
print(codes)
# Out:
# {'tw': 'Taiwan', 'jp': 'Japan', 'hk': 'Hong Kong'}

# %%
import os
import csv

rootPath = os.path.abspath(path="./")
fileName = os.path.join(rootPath, 'csv_data', "個股日成交資訊.csv")

with open(fileName, encoding = 'utf-8', newline = '') as csvfile:
    Dictreader = csv.DictReader(csvfile)
    for item in  Dictreader:
        print(f"證券名稱:", item["證券名稱"], f", 收盤價: ", item["收盤價"])
    #data = list(Dictreader)
    #print(data)
# Out:
# 證券名稱: 元大台灣50 , 收盤價:  72.80
# 證券名稱: 元大中型100 , 收盤價:  26.75
# 證券名稱: 富邦科技 , 收盤價:  55.35
# 證券名稱: 元大電子 , 收盤價:  32.69
# 證券名稱: 元大台商50 , 收盤價:  18.64
# 證券名稱: 元大MSCI金融 , 收盤價:  15.10
# 證券名稱: 元大高股息 , 收盤價:  23.29
# 證券名稱: 富邦摩台 , 收盤價:  48.35
# 證券名稱: 元大寶滬深 , 收盤價:  17.93
# 證券名稱: 元大MSCI台灣 , 收盤價:  34.52
# 證券名稱: 永豐臺灣加權 , 收盤價:  46.63
# 證券名稱: 富邦上証 , 收盤價:  28.22
# 證券名稱: 元大上證50 , 收盤價:  29.24
# 證券名稱: FH滬深 , 收盤價:  21.95
# 證券名稱: 富邦台50 , 收盤價:  41.55
# 證券名稱: 富邦上証+R , 收盤價:  6.67
# 證券名稱: 元大台灣50正2 , 收盤價:  30.66
# 證券名稱: 元大台灣50反1 , 收盤價:  12.90
# 證券名稱: 富邦上証正2 , 收盤價:  35.89
# 證券名稱: 富邦上証反1 , 收盤價:  6.34
# 證券名稱: 元大S&P黃金 , 收盤價:  21.70
# 證券名稱: 國泰中國A50 , 收盤價:  19.31
# 證券名稱: 國泰中國A50+U , 收盤價:  0.00
# 證券名稱: 元大滬深300正2 , 收盤價:  13.72
# 證券名稱: 元大滬深300反1 , 收盤價:  12.85
# 證券名稱: 富邦深100 , 收盤價:  10.71
# 證券名稱: 富邦日本正2 , 收盤價:  12.28
# 證券名稱: 富邦日本反1 , 收盤價:  18.03
# 證券名稱: 元大S&P石油 , 收盤價:  10.25
# 證券名稱: 群益深証中小 , 收盤價:  13.02
# 證券名稱: 群益深証中小+R , 收盤價:  0.00
# 證券名稱: 富邦日本 , 收盤價:  16.79
# 證券名稱: 元大S&P500 , 收盤價:  22.38
# 證券名稱: 元大S&P500正2 , 收盤價:  22.41
# ...
